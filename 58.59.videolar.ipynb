# %% [markdown]
# <a href="https://colab.research.google.com/github/kahramankaya/Anlas-l-rEkonomiYoutube/blob/main/58.59.videolar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#58.video(Test İstatistiği)
#testler parametrik ve non-parametrik diye daima ikiye ayrılır.
#parametrik testler kullanıldıgı zamanlar:normal dagılım olmalı, orneklem syısı n>30 olmalı, veri sürekli olmalı, gruplar arası varyans homojenlıgı(grup sayısı 2 ve fazlasıysa )

# %%
#59.video(Normallik Varsayımı Testleri)
import numpy as np
from scipy import stats
np.random.seed(45)
veri =stats.norm.rvs(loc=38, scale=5, size=500)
print(veri)




#10.dk dayım
# Out:
# [38.13187386 39.30160851 36.02427229 36.97849547 31.64183673 25.01560685
#  39.44840456 33.63347678 39.97036328 42.67552772 37.92157646 39.29797983
#  30.63342879 42.00963298 29.24623807 35.52474034 32.95699595 38.12622093
#  37.39246573 30.26563409 34.96528013 31.03093664 34.86152253 39.66316077
#  30.29316579 46.3514991  35.50227067 41.36564482 49.24044787 29.72868624
#  35.62801492 36.4904238  33.34486811 43.5549303  37.05158521 44.39204795
#  35.22961441 39.7715137  35.79861914 35.87775586 39.14040812 40.89522083
#  33.72905823 33.79329833 34.72147944 37.26558649 30.9401225  36.64721588
#  43.64651652 31.29870964 36.75351986 46.81746106 35.04020287 33.46094159
#  39.35899809 37.97719165 42.27053468 30.04997558 38.28024493 38.52931283
#  37.54581211 34.43061972 39.01857697 44.01515919 38.42156534 38.81966962
#  39.86875775 36.86546575 34.64362798 39.5705494  45.42209057 41.26082079
#  36.83713316 43.92373093 42.60473656 44.08250394 28.58368597 39.10645989
# ...
