# %% [markdown]
# <a href="https://colab.research.google.com/github/kahramankaya/Anlas-l-rEkonomiYoutube/blob/main/93.video(dogrusall%C4%B1k%20nedir).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#93.video(dogrusallık nedir):bildigım basıt seyler anlatıldı.

# %%
#matplot ile var olan bır dogrusal grafıgı cızme.
x=[2,5,8,9]
y=[8,9,14,25]
import matplotlib.pyplot as plt
plt.plot(x,y)
plt.show()

# %%
#scatter yapısı dogru yerıne nokta koyar.
plt.scatter(x,y)
plt.show()
